# %%
import numpy as np
import matplotlib.pyplot as plt
import json
from pprint import pprint

# %%
json_data=open('hubmoni_pwr.json')
data = json.load(json_data)

# %%
pprint(data[0])
# Out:
# {u'_id': u'53ed2838a13125',
#  u'prio': 3,
#  u'service': u'hubmoni',
#  u'time': u'2014-08-14 21:18:02.661683',
#  u'value': {u'recordingStartTime': u'2014-08-14 21:18:02.701281',
#             u'recordingStopTime': u'2014-08-14 21:18:02.701281',
#             u'value': {u'[82, 10]': {u'card': 1,
#                                      u'current': 90,
#                                      u'dom': u'A',
#                                      u'hub': u'ichub82',
#                                      u'mbid': u'cc15c3955364',
#                                      u'pair': 0,
#                                      u'voltage': 88.956},
#                        u'[82, 11]': {u'card': 1,
#                                      u'current': 89,
#                                      u'dom': u'B',
#                                      u'hub': u'ichub82',
#                                      u'mbid': u'2a78c3a5a950',
#                                      u'pair': 1,
# ...

# %%
pprint(data[0]['value']['value'].keys())
# Out:
# [u'[82, 33]',
#  u'[82, 52]',
#  u'[82, 60]',
#  u'[82, 26]',
#  u'[82, 21]',
#  u'[82, 49]',
#  u'[82, 13]',
#  u'[82, 50]',
#  u'[82, 25]',
#  u'[82, 27]',
#  u'[82, 35]',
#  u'[82, 58]',
#  u'[82, 47]',
#  u'[82, 45]',
#  u'[82, 31]',
#  u'[82, 54]',
#  u'[82, 37]',
#  u'[82, 56]',
#  u'[82, 43]',
#  u'[82, 16]',
#  u'[82, 19]',
#  u'[82, 4]',
#  u'[82, 2]',
#  u'[82, 51]',
#  u'[82, 22]',
#  u'[82, 6]',
#  u'[82, 17]',
#  u'[82, 11]',
#  u'[82, 15]',
#  u'[82, 8]',
#  u'[82, 46]',
#  u'[82, 53]',
#  u'[82, 55]',
#  u'[82, 32]',
#  u'[82, 20]',
#  u'[82, 10]',
#  u'[82, 12]',
#  u'[82, 48]',
#  u'[82, 59]',
#  u'[82, 9]',
#  u'[82, 36]',
#  u'[82, 34]',
#  u'[82, 40]',
#  u'[82, 39]',
#  u'[82, 30]',
#  u'[82, 44]',
#  u'[82, 24]',
#  u'[82, 57]',
#  u'[82, 14]',
#  u'[82, 1]',
#  u'[82, 3]',
#  u'[82, 38]',
#  u'[82, 7]',
#  u'[82, 18]',
#  u'[82, 5]',
#  u'[82, 28]',
#  u'[82, 42]',
#  u'[82, 29]',
#  u'[82, 23]',
#  u'[82, 41]']
